# %% [markdown]
# ### Spark Moive Recommendation
# In this notebook, we will use an Alternating Least Squares (ALS) algorithm with Spark APIs to predict the ratings for the movies in [MovieLens small dataset](https://grouplens.org/datasets/movielens/latest/)

# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
os.environ["PYSPARK_PYTHON"] = "python3"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Part0: Data Import

# %%
spark = SparkSession \
    .builder \
    .appName("moive analysis") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
movies_df = spark.read.load("/FileStore/tables/movies.csv", format='csv', header = True)
ratings_df = spark.read.load("/FileStore/tables/ratings.csv", format='csv', header = True)
links_df = spark.read.load("/FileStore/tables/links.csv", format='csv', header = True)
tags_df = spark.read.load("/FileStore/tables/tags.csv", format='csv', header = True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Part I: Exploratory Data Analysis

# %%
tmp1 = ratings_df.groupBy('userId').count().select(F.min('count')).collect()[0][0]
print('Minimum number of ratings per user is {}'.format(tmp1))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Minimum number of ratings per user is 20
# </div>

# %%
tmp2 = ratings_df.groupBy('movieId').count().select(F.min('count')).collect()[0][0]
print('Minimum number of ratings per movie is {}'.format(tmp2))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Minimum number of ratings per movie is 1
# </div>

# %%
tmp1 = ratings_df.groupBy("movieId").count()
tmp1 = tmp1.filter(tmp1['count']==1).count()
tmp2 = ratings_df.select('movieId').distinct().count()
print('{} out of {} movies are rated by only one user'.format(tmp1, tmp2))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">3446 out of 9724 movies are rated by only one user
# </div>

# %%
tmp1 = ratings_df.groupBy("movieId").count().select(F.avg('count')).collect()[0][0]
print('Average number of ratings per movie is {}'.format(tmp1))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Average number of ratings per movie is 10.369806663924312
# </div>

# %%
tmp2 = ratings_df.groupBy("userId").count().select(F.avg('count')).collect()[0][0]
print('Average number of ratings per user is {}'.format(tmp2))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Average number of ratings per user is 165.30491803278687
# </div>

# %%
movie_num = movies_df.select('movieId').distinct().count()
user_num = ratings_df.select('userId').distinct().count()
rating_num = ratings_df.select('rating').count()
print('Total number of users is {}. '.format(user_num))
print('Total number of movies is {}. '.format(movie_num))
print('Total number of ratings is {}. '.format(rating_num))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Total number of users is 610.
# Total number of movies is 9742.
# Total number of ratings is 100836.
# </div>

# %%
# The sparsity of the movie ratings
# sparcity = 1- rating_num/(movie_num*user_num)
denominator = movie_num*user_num
numerator = rating_num
sparsity = (1-numerator/denominator)*100
print ("The ratings dataframe is ", "%.2f" % sparsity + "% empty.")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The ratings dataframe is  98.30% empty.
# </div>

# %%
movie_num_rated = ratings_df.select('movieId').distinct().count()
print('Total number of movies rated is {}.'.format(movie_num_rated))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Total number of movies rated is 9724.
# </div>

# %%
movies_df.registerTempTable("movies")
ratings_df.registerTempTable("ratings")
links_df.registerTempTable("links")
tags_df.registerTempTable("tags")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Movies not rated before.

# %%
spark.sql(
  '''
SELECT m.*,r.rating
FROM movies m 
    LEFT JOIN ratings r ON m.movieId = r.movieId
WHERE r.rating is Null
'''
).toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>movieId</th>
#       <th>title</th>
#       <th>genres</th>
#       <th>rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1076</td>
#       <td>Innocents, The (1961)</td>
#       <td>Drama|Horror|Thriller</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2939</td>
#       <td>Niagara (1953)</td>
#       <td>Drama|Thriller</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3338</td>
#       <td>For All Mankind (1989)</td>
#       <td>Documentary</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3456</td>
#       <td>Color of Paradise, The (Rang-e khoda) (1999)</td>
#       <td>Drama</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4194</td>
#       <td>I Know Where I'm Going! (1945)</td>
#       <td>Drama|Romance|War</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Movie Genres

# %% [markdown]
# Each movie belongs to more than 1 genre,as shown below. We need to seperate these genres.

# %%
spark.sql(
  '''
SELECT DISTINCT title, genres
FROM movies
  '''
).toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>genres</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Color of Night (1994)</td>
#       <td>Drama|Thriller</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Surviving the Game (1994)</td>
#       <td>Action|Adventure|Thriller</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Little Big League (1994)</td>
#       <td>Comedy|Drama</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Whatever (1998)</td>
#       <td>Drama</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Ronin (1998)</td>
#       <td>Action|Crime|Thriller</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
## Data processing to seperate the genres for a movie
genres_pd_df = spark.sql("SELECT DISTINCT title, genres FROM movies").toPandas()
genres_pd_df['genres'] = genres_pd_df['genres'].apply(lambda x:x.split('|'))
genres_pd_df = pd.concat([genres_pd_df['title'],genres_pd_df['genres'].apply(pd.Series)],axis = 1).set_index('title')
genres_sep_pd_df = genres_pd_df.stack().reset_index(level=0)
genres_sep_pd_df.columns = ['title','genre']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/pyarrow/__init__.py:152: UserWarning: pyarrow.open_stream is deprecated, please use pyarrow.ipc.open_stream
#   warnings.warn(&#34;pyarrow.open_stream is deprecated, please use &#34;
# </div>

# %% [markdown]
# We store all the movie genres in a list called movie_genres_list.

# %%
movie_genres_list = genres_sep_pd_df['genre'].unique().tolist()
print('Here are all the movie genres:'+'\n', movie_genres_list)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Here are all the movie genres:
#  [&#39;Drama&#39;, &#39;Thriller&#39;, &#39;Action&#39;, &#39;Adventure&#39;, &#39;Comedy&#39;, &#39;Crime&#39;, &#39;Film-Noir&#39;, &#39;Horror&#39;, &#39;Mystery&#39;, &#39;Romance&#39;, &#39;War&#39;, &#39;Sci-Fi&#39;, &#39;IMAX&#39;, &#39;Animation&#39;, &#39;Fantasy&#39;, &#39;Documentary&#39;, &#39;Children&#39;, &#39;Musical&#39;, &#39;Western&#39;, &#39;(no genres listed)&#39;]
# </div>

# %% [markdown]
# ### Movie for Each Category

# %%
genres_sep_df = sqlContext.createDataFrame(genres_sep_pd_df)
genres_sep_df.registerTempTable('genres_sep')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.sql(
  '''
SELECT genre,count(*) AS count
FROM genres_sep
GROUP BY 1
ORDER BY 2 DESC
'''
).toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>genre</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Drama</td>
#       <td>4361</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Comedy</td>
#       <td>3756</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Thriller</td>
#       <td>1894</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Action</td>
#       <td>1828</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Romance</td>
#       <td>1596</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# We put each movie under its genre. This is stored in a dictionary called movie_genre_dict, where the key is the genre, and the values is a list that contains the movies belonging to this genre.

# %%
movie_genre_dict = dict()
for _ in movie_genres_list:
  movie_genre_dict[_] = list()
for index, row in genres_sep_pd_df.iterrows():
   movie_genre_dict[row["genre"]].append(row["title"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Let's take a look at the Film-Noir genre as an example.

# %%
print('Here are movies that belong to the crime genre:'+'\n',movie_genre_dict['Film-Noir'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Here are movies that belong to the crime genre:
#  [&#39;Angel Heart (1987)&#39;, &#39;D.O.A. (1988)&#39;, &#34;Killer&#39;s Kiss (1955)&#34;, &#39;Undercurrent (1946)&#39;, &#39;Killers, The (1946)&#39;, &#39;Strange Love of Martha Ivers, The (1946)&#39;, &#39;Night of the Hunter, The (1955)&#39;, &#39;Lost Highway (1997)&#39;, &#39;13 Tzameti (2005)&#39;, &#39;Fury (1936)&#39;, &#39;Renaissance (2006)&#39;, &#39;Out of the Past (1947)&#39;, &#39;This Gun for Hire (1942)&#39;, &#39;Dark Passage (1947)&#39;, &#39;Grifters, The (1990)&#39;, &#39;Strangers on a Train (1951)&#39;, &#39;Hoodlum (1997)&#39;, &#39;High Sierra (1941)&#39;, &#39;Drive (2011)&#39;, &#39;Laura (1944)&#39;, &#39;Wrong Man, The (1956)&#39;, &#39;Patlabor: The Movie (Kidô keisatsu patorebâ: The Movie) (1989)&#39;, &#39;Key Largo (1948)&#39;, &#39;Crossfire (1947)&#39;, &#39;Devil in a Blue Dress (1995)&#39;, &#39;While the City Sleeps (1956)&#39;, &#39;Sorry, Wrong Number (1948)&#39;, &#39;Long Goodbye, The (1973)&#39;, &#39;Brick (2005)&#39;, &#34;Miller&#39;s Crossing (1990)&#34;, &#39;Postman Always Rings Twice, The (1946)&#39;, &#39;Rififi (Du rififi chez les hommes) (1955)&#39;, &#39;Bullet to the Head (2012)&#39;, &#39;Maltese Falcon, The (1941)&#39;, &#39;Pickup on South Street (1953)&#39;, &#39;L.A. Confidential (1997)&#39;, &#39;Foreign Correspondent (1940)&#39;, &#39;Johnny Eager (1942)&#39;, &#39;Mildred Pierce (1945)&#39;, &#39;White Heat (1949)&#39;, &#39;Gilda (1946)&#39;, &#39;Call Northside 777 (1948)&#39;, &#39;Big Sleep, The (1946)&#39;, &#39;Third Man, The (1949)&#39;, &#39;Notorious (1946)&#39;, &#39;Dark City (1998)&#39;, &#39;Sin City (2005)&#39;, &#39;Suture (1993)&#39;, &#39;House of Games (1987)&#39;, &#39;Letter, The (1940)&#39;, &#39;Bitter Moon (1992)&#39;, &#39;Trou, Le (Hole, The) (Night Watch, The) (1960)&#39;, &#39;Tinker Tailor Soldier Spy (2011)&#39;, &#39;Stranger, The (1946)&#39;, &#39;You Only Live Once (1937)&#39;, &#39;Angels with Dirty Faces (1938)&#39;, &#39;M (1931)&#39;, &#39;Down by Law (1986)&#39;, &#39;Lady from Shanghai, The (1947)&#39;, &#39;Limits of Control, The (2009)&#39;, &#39;Suddenly (1954)&#39;, &#39;Mulholland Drive (2001)&#39;, &#39;Born to Kill (1947)&#39;, &#39;Chinatown (1974)&#39;, &#39;Killing, The (1956)&#39;, &#39;Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)&#39;, &#39;Too Late for Tears (1949)&#39;, &#39;2 Days in the Valley (1996)&#39;, &#39;Sweet Smell of Success (1957)&#39;, &#39;Suspicion (1941)&#39;, &#39;In a Lonely Place (1950)&#39;, &#39;Double Life, A (1947)&#39;, &#39;Touch of Evil (1958)&#39;, &#39;Blood Simple (1984)&#39;, &#39;Pure Formality, A (Pura formalità, Una) (1994)&#39;, &#39;Asphalt Jungle, The (1950)&#39;, &#39;High and Low (Tengoku to jigoku) (1963)&#39;, &#39;D.O.A. (1950)&#39;, &#39;Harder They Fall, The (1956)&#39;, &#39;Detour (1945)&#39;, &#39;Kiss Me Deadly (1955)&#39;, &#39;Rubber (2010)&#39;, &#39;One False Move (1992)&#39;, &#39;I Am a Fugitive from a Chain Gang (1932)&#39;, &#39;This World, Then the Fireworks (1997)&#39;, &#39;Double Indemnity (1944)&#39;, &#39;Stray Dog (Nora inu) (1949)&#39;]
# </div>

# %% [markdown]
# ## Part2: Spark ALS based approach for training model
# We will use an Spark ML to predict the ratings, so let's reload "ratings.csv" using ``sc.textFile`` and then convert it to the form of (user, item, rating) tuples.

# %%
ratings_df.toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>userId</th>
#       <th>movieId</th>
#       <th>rating</th>
#       <th>timestamp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1</td>
#       <td>4.0</td>
#       <td>964982703</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>3</td>
#       <td>4.0</td>
#       <td>964981247</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>6</td>
#       <td>4.0</td>
#       <td>964982224</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>47</td>
#       <td>5.0</td>
#       <td>964983815</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>50</td>
#       <td>5.0</td>
#       <td>964982931</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
movie_ratings_df=ratings_df.drop('timestamp')
movie_ratings_df.toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>userId</th>
#       <th>movieId</th>
#       <th>rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>3</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>6</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>47</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>50</td>
#       <td>5.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Data type convert
from pyspark.sql.types import IntegerType, FloatType
movie_ratings_df = movie_ratings_df.withColumn("userId", movie_ratings_df["userId"].cast(IntegerType()))
movie_ratings_df = movie_ratings_df.withColumn("movieId", movie_ratings_df["movieId"].cast(IntegerType()))
movie_ratings_df = movie_ratings_df.withColumn("rating", movie_ratings_df["rating"].cast(FloatType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
movie_ratings_df.toPandas().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>userId</th>
#       <th>movieId</th>
#       <th>rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>3</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>6</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>47</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>50</td>
#       <td>5.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### ALS Model Selection and Evaluation
#
# With the ALS model, we can use a grid search to find the optimal hyperparameters.

# %%
# import package
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.recommendation import ALS
from pyspark.ml.tuning import CrossValidator,ParamGridBuilder
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Create test and train set
(training,test)=movie_ratings_df.randomSplit([0.8,0.2],seed = 42)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## We will tune the hyperparameters using ParamGridBuilder and CrossValidator.

# %%
#Create ALS model
als = ALS(userCol="userId", itemCol="movieId", ratingCol="rating",coldStartStrategy = 'drop',nonnegative = True, implicitPrefs = False)
# Confirm that a model called "als" was created
type(als)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[129]: pyspark.ml.recommendation.ALS</div>

# %%
#Tune model using ParamGridBuilder
# We will just tune rank and regParam considering long run time, after we get the have combination, we will use larger iterations.
param_grid = ParamGridBuilder() \
            .addGrid(als.rank, [3,5,10]) \
            .addGrid(als.maxIter, [10]) \
            .addGrid(als.regParam, [0.05,0.15,0.25]) \
            .build()
print ("Num models to be tested: ", len(param_grid))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Num models to be tested:  9
# </div>

# %%
# Define evaluator as RMSE
evaluator = RegressionEvaluator(metricName="rmse", labelCol="rating", predictionCol="prediction")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Build Cross validation 
cv = CrossValidator(estimator=als, estimatorParamMaps=param_grid, evaluator=evaluator, numFolds=3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Fit ALS model to training data
model = cv.fit(training)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/ml/util.py:791: UserWarning: Can not find mlflow. To enable mlflow logging, install MLflow library from PyPi.
#   warnings.warn(_MLflowInstrumentation._NO_MLFLOW_WARNING)
# </div>

# %%
#Extract best model from the tuning exercise using ParamGridBuilder
best_model = model.bestModel
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Generate predictions and evaluate using RMSE
predictions=best_model.transform(test)
rmse = evaluator.evaluate(predictions)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Print evaluation metrics and model parameters
print ("**Best Model**")
print ("RMSE = "+str(rmse))
print (" Rank:",best_model._java_obj.parent().getRank())   #parent()method will return an estimator,you can get the best params then
print (" MaxIter:",best_model._java_obj.parent().getMaxIter())
print (" RegParam:",best_model._java_obj.parent().getRegParam())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">RMSE = 0.8736197761693623
# **Best Model**
#  Rank: 10
#  MaxIter: 10
#  RegParam: 0.15
# </div>

# %% [markdown]
# ### Increase iteration number and Model testing

# %%
#Increase the interation for the best ALS model
#coldStartStrategy = 'drop' is important, otherwise, you will recieve rmse = nan
#Spark allows users to set the coldStartStrategy parameter to “drop” in order to drop any rows in the DataFrame of predictions that contain NaN values. 
als_50 = ALS(userCol="userId", itemCol="movieId", ratingCol="rating",rank = 10, maxIter = 50,regParam = 0.15, nonnegative = True, coldStartStrategy = 'drop',implicitPrefs = False)
#fit the model to training data
best_model_50 = als_50.fit(training)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#generate predictions on test data
prediction_50 = best_model_50.transform(test)

# %%
#tell spark how to evaluate predictions
evaluator_50 = RegressionEvaluator(metricName="rmse", labelCol="rating", predictionCol="prediction")
#obtain rmse
rmse_50 = evaluator_50.evaluate(prediction_50)
#print rmse
print('RMSE=',rmse_50)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1916829159551905&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span> evaluator_50 <span class="ansi-blue-fg">=</span> RegressionEvaluator<span class="ansi-blue-fg">(</span>metricName<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#34;rmse&#34;</span><span class="ansi-blue-fg">,</span> labelCol<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#34;rating&#34;</span><span class="ansi-blue-fg">,</span> predictionCol<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#34;prediction&#34;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span> <span class="ansi-red-fg">#obtain rmse</span>
# <span class="ansi-green-fg">----&gt; 4</span><span class="ansi-red-fg"> </span>rmse_50 <span class="ansi-blue-fg">=</span> evaluator_50<span class="ansi-blue-fg">.</span>evaluate<span class="ansi-blue-fg">(</span>prediction_50<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span> <span class="ansi-red-fg">#print rmse</span>
# <span class="ansi-green-intense-fg ansi-bold">      6</span> print<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;RMSE=&#39;</span><span class="ansi-blue-fg">,</span>rmse_50<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;prediction_50&#39; is not defined</div>

# %%
prediction_50_pd_df = prediction_50.toPandas()[['movieId','rating','prediction']].set_index('movieId')
display(prediction_50_pd_df.plot(style=['o','rx']))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1916829159551908&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>prediction_50_pd_df <span class="ansi-blue-fg">=</span> prediction_50<span class="ansi-blue-fg">.</span>toPandas<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;movieId&#39;</span><span class="ansi-blue-fg">,</span><span class="ansi-blue-fg">&#39;rating&#39;</span><span class="ansi-blue-fg">,</span><span class="ansi-blue-fg">&#39;prediction&#39;</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">.</span>set_index<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;movieId&#39;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span> display<span class="ansi-blue-fg">(</span>prediction_50_pd_df<span class="ansi-blue-fg">.</span>plot<span class="ansi-blue-fg">(</span>style<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;o&#39;</span><span class="ansi-blue-fg">,</span><span class="ansi-blue-fg">&#39;rx&#39;</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;prediction_50&#39; is not defined</div>

# %%
# round the prediction to a scale of 1-5
def round_to_5scale(x):
  if x<=round(x) and 0.5<=x<=5:
    return round(x)-0.5 if round(x)-x>0.25 else round(x)
  if x>round(x) and 0.5<=x<=5:
    return round(x)+0.5 if x-round(x)>0.25 else round(x)
  if x>5:
    return 5
  if x<0.5:
    return 0.5
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
prediction_50_pd_df['prediction'] = prediction_50_pd_df['prediction'].apply(lambda x: round_to_5scale(x))
display(prediction_50_pd_df.plot(style=['o','rx']))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1916829159551910&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>prediction_50_pd_df<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;prediction&#39;</span><span class="ansi-blue-fg">]</span> <span class="ansi-blue-fg">=</span> prediction_50_pd_df<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;prediction&#39;</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">.</span>apply<span class="ansi-blue-fg">(</span><span class="ansi-green-fg">lambda</span> x<span class="ansi-blue-fg">:</span> round_to_5scale<span class="ansi-blue-fg">(</span>x<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span> display<span class="ansi-blue-fg">(</span>prediction_50_pd_df<span class="ansi-blue-fg">.</span>plot<span class="ansi-blue-fg">(</span>style<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;o&#39;</span><span class="ansi-blue-fg">,</span><span class="ansi-blue-fg">&#39;rx&#39;</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;prediction_50_pd_df&#39; is not defined</div>

# %%
prediction_50_user_pd_df = prediction_50.toPandas()[['userId','rating','prediction']].set_index('userId')
prediction_50_user_pd_df['prediction'] = prediction_50_user_pd_df['prediction'].apply(lambda x: round_to_5scale(x))
display(prediction_50_user_pd_df.plot(style=['o','rx']))

# %% [markdown]
# ### Apply model to all data and see the performance

# %%
#Best_model RMSE
alldata=best_model.transform(movie_ratings_df)
rmse = evaluator.evaluate(alldata)
print ("RMSE = "+str(rmse))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">RMSE = 0.6975433153657589
# </div>

# %%
#Best_model_50 RMSE
alldata=best_model_50.transform(movie_ratings_df)
rmse = evaluator.evaluate(alldata)
print ("RMSE = "+str(rmse))

# %%
alldata.registerTempTable("alldata")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sparl.sql(
  '''
SELECT *
FROM movies
	JOIN alldata ON movies.movieId = alldata.movieId
  '''
).toPandas().head()

# %%
alldata_pd_df = alldata.toPandas()[['movieId','rating','prediction']].set_index('movieId')
alldata_pd_df.plot(style=['o','rx'])
display()

# %%
alldata_pd_df['prediction'] = alldata_pd_df['prediction'].apply(lambda x: round_to_5scale(x))
alldata_pd_df.plot(style=['o','rx'])
display()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ArrowIOError</span>                              Traceback (most recent call last)
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/dataframe.py</span> in <span class="ansi-cyan-fg">_collectAsArrow</span><span class="ansi-blue-fg">(self)</span>
# <span class="ansi-green-intense-fg ansi-bold">   2232</span>             <span class="ansi-green-fg">try</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">-&gt; 2233</span><span class="ansi-red-fg">                 </span><span class="ansi-green-fg">return</span> list<span class="ansi-blue-fg">(</span>_load_from_socket<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">(</span>port<span class="ansi-blue-fg">,</span> auth_secret<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> ArrowStreamSerializer<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   2234</span>             <span class="ansi-green-fg">finally</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/serializers.py</span> in <span class="ansi-cyan-fg">load_stream</span><span class="ansi-blue-fg">(self, stream)</span>
# <span class="ansi-green-intense-fg ansi-bold">    232</span>         <span class="ansi-green-fg">import</span> pyarrow <span class="ansi-green-fg">as</span> pa
# <span class="ansi-green-fg">--&gt; 233</span><span class="ansi-red-fg">         </span>reader <span class="ansi-blue-fg">=</span> pa<span class="ansi-blue-fg">.</span>open_stream<span class="ansi-blue-fg">(</span>stream<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    234</span>         <span class="ansi-green-fg">for</span> batch <span class="ansi-green-fg">in</span> reader<span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.7/site-packages/pyarrow/__init__.py</span> in <span class="ansi-cyan-fg">open_stream</span><span class="ansi-blue-fg">(source)</span>
# <span class="ansi-green-intense-fg ansi-bold">    153</span>                   &#34;pyarrow.ipc.open_stream&#34;)
# <span class="ansi-green-fg">--&gt; 154</span><span class="ansi-red-fg">     </span><span class="ansi-green-fg">return</span> ipc<span class="ansi-blue-fg">.</span>open_stream<span class="ansi-blue-fg">(</span>source<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    155</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.7/site-packages/pyarrow/ipc.py</span> in <span class="ansi-cyan-fg">open_stream</span><span class="ansi-blue-fg">(source)</span>
# <span class="ansi-green-intense-fg ansi-bold">    122</span>     &#34;&#34;&#34;
# <span class="ansi-green-fg">--&gt; 123</span><span class="ansi-red-fg">     </span><span class="ansi-green-fg">return</span> RecordBatchStreamReader<span class="ansi-blue-fg">(</span>source<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    124</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.7/site-packages/pyarrow/ipc.py</span> in <span class="ansi-cyan-fg">__init__</span><span class="ansi-blue-fg">(self, source)</span>
# <span class="ansi-green-intense-fg ansi-bold">     57</span>     <span class="ansi-green-fg">def</span> __init__<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">,</span> source<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">---&gt; 58</span><span class="ansi-red-fg">         </span>self<span class="ansi-blue-fg">.</span>_open<span class="ansi-blue-fg">(</span>source<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     59</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.7/site-packages/pyarrow/ipc.pxi</span> in <span class="ansi-cyan-fg">pyarrow.lib._RecordBatchStreamReader._open</span><span class="ansi-blue-fg">()</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.7/site-packages/pyarrow/error.pxi</span> in <span class="ansi-cyan-fg">pyarrow.lib.check_status</span><span class="ansi-blue-fg">()</span>
#
# <span class="ansi-red-fg">ArrowIOError</span>:
#
# During handling of the above exception, another exception occurred:
#
# <span class="ansi-red-fg">Py4JJavaError</span>                             Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-468122641793308&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>alldata_pd_df <span class="ansi-blue-fg">=</span> alldata<span class="ansi-blue-fg">.</span>toPandas<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;movieId&#39;</span><span class="ansi-blue-fg">,</span><span class="ansi-blue-fg">&#39;rating&#39;</span><span class="ansi-blue-fg">,</span><span class="ansi-blue-fg">&#39;prediction&#39;</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">.</span>set_index<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;movieId&#39;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span> alldata_pd_df<span class="ansi-blue-fg">.</span>plot<span class="ansi-blue-fg">(</span>style<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;o&#39;</span><span class="ansi-blue-fg">,</span><span class="ansi-blue-fg">&#39;rx&#39;</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span> display<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/dataframe.py</span> in <span class="ansi-cyan-fg">toPandas</span><span class="ansi-blue-fg">(self)</span>
# <span class="ansi-green-intense-fg ansi-bold">   2170</span>                         _check_dataframe_localize_timestamps
# <span class="ansi-green-intense-fg ansi-bold">   2171</span>                     <span class="ansi-green-fg">import</span> pyarrow
# <span class="ansi-green-fg">-&gt; 2172</span><span class="ansi-red-fg">                     </span>batches <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>_collectAsArrow<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   2173</span>                     <span class="ansi-green-fg">if</span> len<span class="ansi-blue-fg">(</span>batches<span class="ansi-blue-fg">)</span> <span class="ansi-blue-fg">&gt;</span> <span class="ansi-cyan-fg">0</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">   2174</span>                         table <span class="ansi-blue-fg">=</span> pyarrow<span class="ansi-blue-fg">.</span>Table<span class="ansi-blue-fg">.</span>from_batches<span class="ansi-blue-fg">(</span>batches<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/dataframe.py</span> in <span class="ansi-cyan-fg">_collectAsArrow</span><span class="ansi-blue-fg">(self)</span>
# <span class="ansi-green-intense-fg ansi-bold">   2233</span>                 <span class="ansi-green-fg">return</span> list<span class="ansi-blue-fg">(</spa

# %%
alldata_user_pd_df = alldata.toPandas()[['userId','rating','prediction']].set_index('userId')
alldata_user_pd_df['prediction'] = alldata_user_pd_df['prediction'].apply(lambda x: round_to_5scale(x))
display(alldata_user_pd_df.plot(style=['o','rx']))

# %% [markdown]
# ### Let's look more closely on the user and movie data to decide which user to recommend.

# %%
ratings_info_df = movie_ratings_df.groupBy('movieId').avg('rating')
movie_ratings_count= movie_ratings_df.groupBy('movieId').count()
ratings_info_df = ratings_info_df.join(movie_ratings_count,'movieId','left').join(movies_df,'movieId','left')
ratings_info_df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-----------------+-----+--------------------+--------------------+
# movieId|      avg(rating)|count|               title|              genres|
# +-------+-----------------+-----+--------------------+--------------------+
#    1580|3.487878787878788|  165|Men in Black (a.k...|Action|Comedy|Sci-Fi|
#    2366|             3.64|   25|    King Kong (1933)|Action|Adventure|...|
#    3175|             3.58|   75| Galaxy Quest (1999)|Adventure|Comedy|...|
#    1088|3.369047619047619|   42|Dirty Dancing (1987)|Drama|Musical|Rom...|
#   32460|             4.25|    4|Knockin&#39; on Heave...|Action|Comedy|Cri...|
# +-------+-----------------+-----+--------------------+--------------------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# ### UserId order by rating count

# %%
ratings_df.groupBy("userId").count().toPandas().sort_values(by = 'count',ascending=False).head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>userId</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>345</th>
#       <td>414</td>
#       <td>2698</td>
#     </tr>
#     <tr>
#       <th>472</th>
#       <td>599</td>
#       <td>2478</td>
#     </tr>
#     <tr>
#       <th>280</th>
#       <td>474</td>
#       <td>2108</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>448</td>
#       <td>1864</td>
#     </tr>
#     <tr>
#       <th>193</th>
#       <td>274</td>
#       <td>1346</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# We will recommend user 414 and 599 as they have the highest rating count. This means the recommendations to them would be more reliable.

# %% [markdown]
# ### Histogram of rating counts

# %%
display(ratings_info_df.toPandas()['count'].hist(bins=50,log= True))

# %% [markdown]
# ### Histogram of the ratings

# %%
display(ratings_info_df.toPandas()['avg(rating)'].hist(bins=50))

# %%
fig, ax = plt.subplots()
g = sns.jointplot(x='avg(rating)', y='count', data=ratings_info_df.toPandas())
display(g.fig)

# %% [markdown]
# ## Recommend moive to users with id: 414, 599.

# %%
# use the recommendation function of ALS
ALS_recommendations = best_model.recommendForAllUsers(10)
ALS_recommendations.filter(ALS_recommendations['userId'] == 599).show()

# %% [markdown]
# We need to process the above dataframe for readability.

# %%
# Data procesing of the ALS_recommendations dataframe
from pyspark.sql.functions import explode,col
recommendations_df = (ALS_recommendations\
                      .select("userId",\
                              explode("recommendations")\
                              .alias("recommendation"))\
                      .select("userId", "recommendation.movieId",\
                              col("recommendation.rating")\
                              .alias('prediction')))
recommendations_df.show(3)

# %%
# we only recommend movies that have not been watched by users before
recommendations_df = recommendations_df.join(movies_df,["movieId"],"left").join(ratings_df,['movieId','UserId'],'left')
recommendations_df = recommendations_df.drop('timestamp')
recommendations_df = recommendations_df.filter(ratings_df.rating.isNull())
recommendations_df.show()

# %% [markdown]
# We will only recommend movies that the users haven't watched/rated.
#
# movies recommendations for user 414

# %%
recommendations_df.filter(recommendations_df['userId'] == 414).show()

# %% [markdown]
# movies recommendations for user 599

# %%
recommendations_df.filter(recommendations_df['userId'] == 599).show()

# %%
# Another way is to recommendForUserSubset function
#users = ALS_recommendations.filter(ALS_recommendations['userId'] == 575)
#ALS_recommendations_target = best_model.recommendForUserSubset(users,1)
#ALS_recommendations_target.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Find the similar moives for moive with id: 464, 471

# %% [markdown]
# The similarites of different movies can be recognized from correlations of their user ratings. Let's say user A and B both gave movie 1,2 5 star rating. This indicates that the movie 1 and 2 might be highily similar.
#
# However, we have a challenge in that some of the movies have very few ratings and may end up having high correlation simply because one or two people gave them a 5 star rating. We can fix this by setting a threshold for the number of ratings. From the histogram earlier we saw a sharp decline in number of ratings from 100. Therefore we will choose this as our threshold.

# %%
movie_matrix = movie_ratings_df.toPandas().pivot_table(index='userId', columns='movieId', values='rating')

# %%
def find_similar_movie(x):
  movie_x_rating = movie_matrix[x]
  similar_to_x=movie_matrix.corrwith(movie_x_rating).reset_index(level=0)
  similar_to_x.dropna(axis = 0,how = 'any',inplace=True)
  similar_to_x.columns = ['movieId','correlation']
  
  similar_to_x_df = sqlContext.createDataFrame(similar_to_x)
  similar_to_x_movie = similar_to_x_df.join(ratings_info_df,'movieId','left').toPandas()[['movieId','correlation','title','count']]
  res = similar_to_x_movie[similar_to_x_movie['count']>100].sort_values(by = 'correlation',ascending = False)
  return similar_to_x,res

# %% [markdown]
# We will only find similar movies that have been rated more than 100 times.
#
# movies similar to movie 471

# %%
# Movies similar to 471
corr_471,similar_to_471_movie = find_similar_movie(471)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2095080894636727&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-red-fg"># Movies similar to 471</span>
# <span class="ansi-green-fg">----&gt; 2</span><span class="ansi-red-fg"> </span>corr_471<span class="ansi-blue-fg">,</span>similar_to_471_movie <span class="ansi-blue-fg">=</span> find_similar_movie<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">471</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">&lt;command-2095080894636725&gt;</span> in <span class="ansi-cyan-fg">find_similar_movie</span><span class="ansi-blue-fg">(x)</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-green-fg">def</span> find_similar_movie<span class="ansi-blue-fg">(</span>x<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">----&gt; 2</span><span class="ansi-red-fg">   </span>movie_x_rating <span class="ansi-blue-fg">=</span> movie_matrix<span class="ansi-blue-fg">[</span>x<span class="ansi-blue-fg">]</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span>   similar_to_x<span class="ansi-blue-fg">=</span>movie_matrix<span class="ansi-blue-fg">.</span>corrwith<span class="ansi-blue-fg">(</span>movie_x_rating<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>reset_index<span class="ansi-blue-fg">(</span>level<span class="ansi-blue-fg">=</span><span class="ansi-cyan-fg">0</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span>   similar_to_x<span class="ansi-blue-fg">.</span>dropna<span class="ansi-blue-fg">(</span>axis <span class="ansi-blue-fg">=</span> <span class="ansi-cyan-fg">0</span><span class="ansi-blue-fg">,</span>how <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#39;any&#39;</span><span class="ansi-blue-fg">,</span>inplace<span class="ansi-blue-fg">=</span><span class="ansi-green-fg">True</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span>   similar_to_x<span class="ansi-blue-fg">.</span>columns <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;movieId&#39;</span><span class="ansi-blue-fg">,</span><span class="ansi-blue-fg">&#39;correlation&#39;</span><span class="ansi-blue-fg">]</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;movie_matrix&#39; is not defined</div>

# %%
corr_471.plot(kind='scatter',x = 'movieId',y='correlation')
display()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1916829159551926&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>corr_471<span class="ansi-blue-fg">.</span>plot<span class="ansi-blue-fg">(</span>kind<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;scatter&#39;</span><span class="ansi-blue-fg">,</span>x <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#39;movieId&#39;</span><span class="ansi-blue-fg">,</span>y<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;correlation&#39;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span> display<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;corr_471&#39; is not defined</div>

# %%
similar_to_471_movie.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1916829159551927&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>similar_to_471_movie<span class="ansi-blue-fg">.</span>head<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;similar_to_471_movie&#39; is not defined</div>

# %% [markdown]
# movies similar to movie 464

# %%
# Movies similar to 464
corr_464,similar_to_464_movie = find_similar_movie(464)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1079435757161930&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-red-fg"># Movies similar to 464</span>
# <span class="ansi-green-fg">----&gt; 2</span><span class="ansi-red-fg"> </span>corr_464<span class="ansi-blue-fg">,</span>similar_to_464_movie <span class="ansi-blue-fg">=</span> find_similar_movie<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">464</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">&lt;command-2095080894636725&gt;</span> in <span class="ansi-cyan-fg">find_similar_movie</span><span class="ansi-blue-fg">(x)</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-green-fg">def</span> find_similar_movie<span class="ansi-blue-fg">(</span>x<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">----&gt; 2</span><span class="ansi-red-fg">   </span>movie_x_rating <span class="ansi-blue-fg">=</span> movie_matrix<span class="ansi-blue-fg">[</span>x<span class="ansi-blue-fg">]</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span>   similar_to_x<span class="ansi-blue-fg">=</span>movie_matrix<span class="ansi-blue-fg">.</span>corrwith<span class="ansi-blue-fg">(</span>movie_x_rating<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>reset_index<span class="ansi-blue-fg">(</span>level<span class="ansi-blue-fg">=</span><span class="ansi-cyan-fg">0</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span>   similar_to_x<span class="ansi-blue-fg">.</span>dropna<span class="ansi-blue-fg">(</span>axis <span class="ansi-blue-fg">=</span> <span class="ansi-cyan-fg">0</span><span class="ansi-blue-fg">,</span>how <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#39;any&#39;</span><span class="ansi-blue-fg">,</span>inplace<span class="ansi-blue-fg">=</span><span class="ansi-green-fg">True</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span>   similar_to_x<span class="ansi-blue-fg">.</span>columns <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;movieId&#39;</span><span class="ansi-blue-fg">,</span><span class="ansi-blue-fg">&#39;correlation&#39;</span><span class="ansi-blue-fg">]</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;movie_matrix&#39; is not defined</div>

# %%
corr_464.plot(kind='scatter',x = 'movieId',y='correlation')
display()

# %%
similar_to_464_movie.head()

# %% [markdown]
# ## Report
# In this project, the movie data from movie lens data set which includes about 600 users and 9500 movies were analyzed to gain insights on movie recomendations to users and finding similar movies. At the beginning, we calculate the sparisity of the movie ratings which is 98.3%, this tells us that the ratings dataframe is mostly empty, which brings significance to predict the user ratings from what we have.
#
# To achieve the goal,the data was analyzed on Spark platform from perfoming data cleaning,processing to model training with Alternating Least Squares (ALS) algorithm.During which, grid search and cross validation were applied to tune the hyperparameters. It is found that using large rank and iterzations would help achieve a low RMSE. Finally, we choose a rank of 10, iterate 50 times and regPram = 0.15,a RMSE of 0.69 was achieved.This means that on average the model predicts 0.69 above or below values of the original ratings matrix.
#
# By successsfully predicting the ratings using the best model, we not only fill the rating dataframe and recommend our users with movies they have never watched, but also find similar movies through their correlations. This brings huge business value to the company.
