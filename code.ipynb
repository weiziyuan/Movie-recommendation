# %% [markdown]
# ### Spark Moive Recommendation
# In this notebook, we will use an Alternating Least Squares (ALS) algorithm with Spark APIs to predict the ratings for the movies in [MovieLens small dataset](https://grouplens.org/datasets/movielens/latest/)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math
# %matplotlib inline
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">%matplotlib inline is not supported in Databricks.
# You can display matplotlib figures using display(). For an example, see https://docs.databricks.com/user-guide/visualizations/matplotlib-and-ggplot.html
# </div>

# %%
import os
os.environ["PYSPARK_PYTHON"] = "python3"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Part1: Data ETL and Data Exploration

# %%
from pyspark.sql import SparkSession
spark = SparkSession \
    .builder \
    .appName("moive analysis") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
movies_df = spark.read.load("/FileStore/tables/movies.csv", format='csv', header = True)
ratings_df = spark.read.load("/FileStore/tables/ratings.csv", format='csv', header = True)
links_df = spark.read.load("/FileStore/tables/links.csv", format='csv', header = True)
tags_df = spark.read.load("/FileStore/tables/tags.csv", format='csv', header = True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
movies_df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------------------+--------------------+
# movieId|               title|              genres|
# +-------+--------------------+--------------------+
#       1|    Toy Story (1995)|Adventure|Animati...|
#       2|      Jumanji (1995)|Adventure|Childre...|
#       3|Grumpier Old Men ...|      Comedy|Romance|
#       4|Waiting to Exhale...|Comedy|Drama|Romance|
#       5|Father of the Bri...|              Comedy|
# +-------+--------------------+--------------------+
# only showing top 5 rows
#
# </div>

# %%
ratings_df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-------+------+---------+
# userId|movieId|rating|timestamp|
# +------+-------+------+---------+
#      1|      1|   4.0|964982703|
#      1|      3|   4.0|964981247|
#      1|      6|   4.0|964982224|
#      1|     47|   5.0|964983815|
#      1|     50|   5.0|964982931|
# +------+-------+------+---------+
# only showing top 5 rows
#
# </div>

# %%
links_df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------+------+
# movieId| imdbId|tmdbId|
# +-------+-------+------+
#       1|0114709|   862|
#       2|0113497|  8844|
#       3|0113228| 15602|
#       4|0114885| 31357|
#       5|0113041| 11862|
# +-------+-------+------+
# only showing top 5 rows
#
# </div>

# %%
tags_df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-------+---------------+----------+
# userId|movieId|            tag| timestamp|
# +------+-------+---------------+----------+
#      2|  60756|          funny|1445714994|
#      2|  60756|Highly quotable|1445714996|
#      2|  60756|   will ferrell|1445714992|
#      2|  89774|   Boxing story|1445715207|
#      2|  89774|            MMA|1445715200|
# +------+-------+---------------+----------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# ## Part I: Exploratory Data Analysis

# %%
tmp1 = ratings_df.groupBy("userID").count().toPandas()['count'].min()
tmp2 = ratings_df.groupBy("movieId").count().toPandas()['count'].min()
print('For the users that rated movies and the movies that were rated:')
print('Minimum number of ratings per user is {}'.format(tmp1))
print('Minimum number of ratings per movie is {}'.format(tmp2))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/pyarrow/__init__.py:152: UserWarning: pyarrow.open_stream is deprecated, please use pyarrow.ipc.open_stream
#   warnings.warn(&#34;pyarrow.open_stream is deprecated, please use &#34;
# /databricks/python/lib/python3.7/site-packages/pyarrow/__init__.py:152: UserWarning: pyarrow.open_stream is deprecated, please use pyarrow.ipc.open_stream
#   warnings.warn(&#34;pyarrow.open_stream is deprecated, please use &#34;
# For the users that rated movies and the movies that were rated:
# Minimum number of ratings per user is 20
# Minimum number of ratings per movie is 1
# </div>

# %%
tmp1 = sum(ratings_df.groupBy("movieId").count().toPandas()['count'] == 1)
tmp2 = ratings_df.select('movieId').distinct().count()
print('{} out of {} movies are rated by only one user'.format(tmp1, tmp2))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/pyarrow/__init__.py:152: UserWarning: pyarrow.open_stream is deprecated, please use pyarrow.ipc.open_stream
#   warnings.warn(&#34;pyarrow.open_stream is deprecated, please use &#34;
# 3446 out of 9724 movies are rated by only one user
# </div>

# %%
tmp1 = ratings_df.groupBy("movieId").count().toPandas()['count'].mean()
tmp2 = ratings_df.groupBy("userId").count().toPandas()['count'].mean()
print('Average number of ratings per movie is {}'.format(tmp1))
print('Average number of ratings per user is {}'.format(tmp2))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/pyarrow/__init__.py:152: UserWarning: pyarrow.open_stream is deprecated, please use pyarrow.ipc.open_stream
#   warnings.warn(&#34;pyarrow.open_stream is deprecated, please use &#34;
# /databricks/python/lib/python3.7/site-packages/pyarrow/__init__.py:152: UserWarning: pyarrow.open_stream is deprecated, please use pyarrow.ipc.open_stream
#   warnings.warn(&#34;pyarrow.open_stream is deprecated, please use &#34;
# Average number of ratings per movie is 10.369806663924312
# Average number of ratings per user is 165.30491803278687
# </div>

# %%
movies_df.registerTempTable("movies")
ratings_df.registerTempTable("ratings")
links_df.registerTempTable("links")
tags_df.registerTempTable("tags")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### The number of Users

# %%
# %sql 
SELECT Count(DISTINCT userId) AS number_of_users 
FROM ratings
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>number_of_users</th></tr></thead><tbody><tr><td>610</td></tr></tbody></table></div>

# %% [markdown]
# ###The number of Movies

# %%
# %sql 
SELECT Count(DISTINCT movieID) AS number_of_movies
FROM movies
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>number_of_movies</th></tr></thead><tbody><tr><td>9742</td></tr></tbody></table></div>

# %% [markdown]
# ### The sparsity of the movie ratings
#
# ### sparcity = 1- rating_num/(movie_num*user_num)

# %%
movie_num = ratings_df.select('movieId').distinct().count()
user_num = ratings_df.select('userId').distinct().count()
rating_num = ratings_df.select('rating').count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
denominator = movie_num*user_num
numerator = rating_num
sparsity = (1-numerator/denominator)*100
print ("The ratings dataframe is ", "%.2f" % sparsity + "% empty.")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The ratings dataframe is  98.30% empty.
# </div>

# %% [markdown]
# ### Movies rated by users.

# %%
# %sql 
SELECT Count(DISTINCT movieID) AS movies_rated
FROM ratings
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movies_rated</th></tr></thead><tbody><tr><td>9724</td></tr></tbody></table></div>

# %% [markdown]
# ### Movies not rated before.

# %%
# %sql
SELECT m.*,r.rating
FROM movies m 
    LEFT JOIN ratings r ON m.movieId = r.movieId
WHERE r.rating is Null
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movieId</th><th>title</th><th>genres</th><th>rating</th></tr></thead><tbody><tr><td>1076</td><td>Innocents, The (1961)</td><td>Drama|Horror|Thriller</td><td>null</td></tr><tr><td>2939</td><td>Niagara (1953)</td><td>Drama|Thriller</td><td>null</td></tr><tr><td>3338</td><td>For All Mankind (1989)</td><td>Documentary</td><td>null</td></tr><tr><td>3456</td><td>Color of Paradise, The (Rang-e khoda) (1999)</td><td>Drama</td><td>null</td></tr><tr><td>4194</td><td>I Know Where I'm Going! (1945)</td><td>Drama|Romance|War</td><td>null</td></tr><tr><td>5721</td><td>Chosen, The (1981)</td><td>Drama</td><td>null</td></tr><tr><td>6668</td><td>Road Home, The (Wo de fu qin mu qin) (1999)</td><td>Drama|Romance</td><td>null</td></tr><tr><td>6849</td><td>Scrooge (1970)</td><td>Drama|Fantasy|Musical</td><td>null</td></tr><tr><td>7020</td><td>Proof (1991)</td><td>Comedy|Drama|Romance</td><td>null</td></tr><tr><td>7792</td><td>Parallax View, The (1974)</td><td>Thriller</td><td>null</td></tr><tr><td>8765</td><td>This Gun for Hire (1942)</td><td>Crime|Film-Noir|Thriller</td><td>null</td></tr><tr><td>25855</td><td>Roaring Twenties, The (1939)</td><td>Crime|Drama|Thriller</td><td>null</td></tr><tr><td>26085</td><td>Mutiny on the Bounty (1962)</td><td>Adventure|Drama|Romance</td><td>null</td></tr><tr><td>30892</td><td>In the Realms of the Unreal (2004)</td><td>Animation|Documentary</td><td>null</td></tr><tr><td>32160</td><td>Twentieth Century (1934)</td><td>Comedy</td><td>null</td></tr><tr><td>32371</td><td>Call Northside 777 (1948)</td><td>Crime|Drama|Film-Noir</td><td>null</td></tr><tr><td>34482</td><td>Browning Version, The (1951)</td><td>Drama</td><td>null</td></tr><tr><td>85565</td><td>Chalet Girl (2011)</td><td>Comedy|Romance</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# ### List Movie Genres

# %% [markdown]
# Each movie belongs to more than 1 genre,as shown below. We need to seperate these genres.

# %%
# %sql
SELECT DISTINCT title, genres
FROM movies
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>title</th><th
</td><td>Comedy</td></tr><tr><td>Winter in Prostokvashino (1984)</td><td>Animation</td></tr><tr><td>Young Poisoner's Handbook, The (1995)</td><td>Crime|Drama</td></tr><tr><td>Awfully Big Adventure, An (1995)</td><td>Drama</td></tr><tr><td>Blink (1994)</td><td>Thriller</td></tr><tr><td>Coneheads (1993)</td><td>Comedy|Sci-Fi</td></tr><tr><td>So I Married an Axe Murderer (1993)</td><td>Comedy|Romance|Thriller</td></tr><tr><td>Hype! (1996)</td><td>Documentary</td></tr><tr><td>Head Above Water (1996)</td><td>Comedy|Thriller</td></tr><tr><td>Sliding Doors (1998)</td><td>Drama|Romance</td></tr><tr><td>Madeline (1998)</td><td>Children|Comedy</td></tr><tr><td>Dark Crystal, The (1982)</td><td>Adventure|Fantasy</td></tr><tr><td>Beetlejuice (1988)</td><td>Comedy|Fantasy</td></tr> ...

# %%
## Data processing to seperate the genres for a movie
genres_pd_df = spark.sql("SELECT DISTINCT title, genres FROM movies").toPandas()
genres_pd_df['genres'] = genres_pd_df['genres'].apply(lambda x:x.split('|'))
genres_pd_df = pd.concat([genres_pd_df['title'],genres_pd_df['genres'].apply(pd.Series)],axis = 1).set_index('title')
genres_sep_pd_df = genres_pd_df.stack().reset_index(level=0)
genres_sep_pd_df.columns = ['title','genre']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/pyarrow/__init__.py:152: UserWarning: pyarrow.open_stream is deprecated, please use pyarrow.ipc.open_stream
#   warnings.warn(&#34;pyarrow.open_stream is deprecated, please use &#34;
# </div>

# %% [markdown]
# We store all the movie genres in a list called movie_genres_list.

# %%
movie_genres_list = genres_sep_pd_df['genre'].unique().tolist()
print('Here are all the movie genres:'+'\n', movie_genres_list)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Here are all the movie genres:
#  [&#39;Drama&#39;, &#39;Thriller&#39;, &#39;Action&#39;, &#39;Adventure&#39;, &#39;Comedy&#39;, &#39;Crime&#39;, &#39;Film-Noir&#39;, &#39;Horror&#39;, &#39;Mystery&#39;, &#39;Romance&#39;, &#39;War&#39;, &#39;Sci-Fi&#39;, &#39;IMAX&#39;, &#39;Animation&#39;, &#39;Fantasy&#39;, &#39;Documentary&#39;, &#39;Children&#39;, &#39;Musical&#39;, &#39;Western&#39;, &#39;(no genres listed)&#39;]
# </div>

# %% [markdown]
# ### Movie for Each Category

# %%
genres_sep_df = sqlContext.createDataFrame(genres_sep_pd_df)
genres_sep_df.registerTempTable('genres_sep')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
SELECT genre,count(*) AS count
FROM genres_sep
GROUP BY 1
ORDER BY 2 DESC
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>genre</th><th>count</th></tr></thead><tbody><tr><td>Drama</td><td>4361</td></tr><tr><td>Comedy</td><td>3756</td></tr><tr><td>Thriller</td><td>1894</td></tr><tr><td>Action</td><td>1828</td></tr><tr><td>Romance</td><td>1596</td></tr><tr><td>Adventure</td><td>1263</td></tr><tr><td>Crime</td><td>1199</td></tr><tr><td>Sci-Fi</td><td>980</td></tr><tr><td>Horror</td><td>978</td></tr><tr><td>Fantasy</td><td>779</td></tr><tr><td>Children</td><td>664</td></tr><tr><td>Animation</td><td>611</td></tr><tr><td>Mystery</td><td>573</td></tr><tr><td>Documentary</td><td>440</td></tr><tr><td>War</td><td>382</td></tr><tr><td>Musical</td><td>334</td></tr><tr><td>Western</td><td>167</td></tr><tr><td>IMAX</td><td>158</td></tr><tr><td>Film-Noir</td><td>87</td></tr><tr><td>(no genres listed)</td><td>34</td></tr></tbody></table></div>

# %% [markdown]
# We put each movie under its genre. This is stored in a dictionary called movie_genre_dict, where the key is the genre, and the values is a list that contains the movies belonging to this genre.

# %%
movie_genre_dict = dict()
for _ in movie_genres_list:
  movie_genre_dict[_] = list()
for index, row in genres_sep_pd_df.iterrows():
   movie_genre_dict[row["genre"]].append(row["title"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Let
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-------+------+
# userId|movieId|rating|
# +------+-------+------+
#      1|      1|   4.0|
#      1|      3|   4.0|
#      1|      6|   4.0|
#      1|     47|   5.0|
#      1|     50|   5.0|
#      1|     70|   3.0|
#      1|    101|   5.0|
#      1|    110|   4.0|
#      1|    151|   5.0|
#      1|    157|   5.0|
#      1|    163|   5.0|
#      1|    216|   5.0|
#      1|    223|   3.0|
#      1|    231|   5.0|
#      1|    235|   4.0|
#      1|    260|   5.0|
#      1|    296|   3.0|
#      1|    316|   3.0|
#      1|    333|   5.0|
#      1|    349|   4.0|
# +------+-------+------+
# only showing top 20 rows
#
# </div>

# %%
# Data type convert
from pyspark.sql.types import IntegerType, FloatType
movie_ratings_df = movie_ratings_df.withColumn("userId", movie_ratings_df["userId"].cast(IntegerType()))
movie_ratings_df = movie_ratings_df.withColumn("movieId", movie_ratings_df["movieId"].cast(IntegerType()))
movie_ratings_df = movie_ratings_df.withColumn("rating", movie_ratings_df["rating"].cast(FloatType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
movie_ratings_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-------+------+
# userId|movieId|rating|
# +------+-------+------+
#      1|      1|   4.0|
#      1|      3|   4.0|
#      1|      6|   4.0|
#      1|     47|   5.0|
#      1|     50|   5.0|
#      1|     70|   3.0|
#      1|    101|   5.0|
#      1|    110|   4.0|
#      1|    151|   5.0|
#      1|    157|   5.0|
#      1|    163|   5.0|
#      1|    216|   5.0|
#      1|    223|   3.0|
#      1|    231|   5.0|
#      1|    235|   4.0|
#      1|    260|   5.0|
#      1|    296|   3.0|
#      1|    316|   3.0|
#      1|    333|   5.0|
#      1|    349|   4.0|
# +------+-------+------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ### ALS Model Selection and Evaluation
#
# With the ALS model, we can use a grid search to find the optimal hyperparameters.

# %%
# import package
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.recommendation import ALS
from pyspark.ml.tuning import CrossValidator,ParamGridBuilder
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Create test and train set
(training,test)=movie_ratings_df.randomSplit([0.8,0.2],seed = 42)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## We will tune the hyperparameters using ParamGridBuilder and CrossValidator.

# %%
#Create ALS model
als = ALS(userCol="userId", itemCol="movieId", ratingCol="rating",coldStartStrategy = 'drop',nonnegative = True, implicitPrefs = False)
# Confirm that a model called "als" was created
type(als)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: pyspark.ml.recommendation.ALS</div>

# %%
#Tune model using ParamGridBuilder
# We will just tune rank and regParam considering long run time, after we get the have combination, we will use larger iterations.
param_grid = ParamGridBuilder() \
            .addGrid(als.rank, [3,5,10]) \
            .addGrid(als.maxIter, [10]) \
            .addGrid(als.regParam, [0.05,0.15,0.25]) \
            .build()
print ("Num models to be tested: ", len(param_grid))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Num models to be tested:  9
# </div>

# %%
# Define evaluator as RMSE
evaluator = RegressionEvaluator(metricName="rmse", labelCol="rating", predictionCol="prediction")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Build Cross validation 
cv = CrossValidator(estimator=als, estimatorParamMaps=param_grid, evaluator=evaluator, numFolds=3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Fit ALS model to training data
model = cv.fit(training)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/ml/util.py:791: UserWarning: Can not find mlflow. To enable mlflow logging, install MLflow library from PyPi.
#   warnings.warn(_MLflowInstrumentation._NO_MLFLOW_WARNING)
# </div>

# %%
#Extract best model from the tuning exercise using ParamGridBuilder
best_model = model.bestModel
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Generate predictions and evaluate using RMSE
predictions=best_model.transform(test)
rmse = evaluator.evaluate(predictions)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Print evaluation metrics and model parameters
print ("RMSE = "+str(rmse))
print ("**Best Model**")
print (" Rank:",best_model._java_obj.parent().getRank())   #parent()method will return an estimator,you can get the best params then
print (" MaxIter:",best_model._java_obj.parent().getMaxIter())
print (" RegParam:",best_model._java_obj.parent().getRegParam())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">RMSE = 0.8736197761693623
# **Best Model**
#  Rank: 10
#  MaxIter: 10
#  RegParam: 0.15
# </div>

# %% [markdown]
# ### Increase iteration number and Model testing

# %%
#Increase the interation for the best ALS model
#coldStartStrategy = 'drop' is important, otherwise, you will recieve rmse = nan
#Spark allows users to set the coldStartStrategy parameter to “drop” in order to drop any rows in the DataFrame of predictions that contain NaN values. 
als_50 = ALS(userCol="userId", itemCol="movieId", ratingCol="rating",rank = 10, maxIter = 50,regParam = 0.15, nonnegative = True, coldStartStrategy = 'drop',implicitPrefs = False)
#fit the model to training data
best_model_50 = als_50.fit(training)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#generate predictions on test data
prediction_50 = best_model_50.transform(test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#tell spark how to evaluate predictions
evaluator_50 = RegressionEvaluator(metricName="rmse", labelCol="rating", predictionCol="prediction")
#obtain rmse
rmse_50 = evaluator_50.evaluate(prediction_50)
#print rmse
print('RMSE=',rmse_50)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">RMSE= 0.8705602687772467
# </div>

# %%
prediction_50_pd_df = prediction_50.toPandas()[['movieId','rating','prediction']].set_index('movieId')
display(prediction_50_pd_df.plot(style=['o','rx']))

# %%
# round the prediction to a scale of 1-5
def round_to_5scale(x):
  if x<=round(x) and 0.5<=x<=5:
    return round(x)-0.5 if round(x)-x>0.25 else round(x)
  if x>round(x) and 0.5<=x<=5:
    return round(x)+0.5 if x-round(x)>0.25 else round(x)
  if x>5:
    return 5
  if x<0.5:
    return 0.5
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
prediction_50_pd_df['prediction'] = prediction_50_pd_df['prediction'].apply(lambda x: round_to_5scale(x))
display(prediction_50_pd_df.plot(style=['o','rx']))

# %%
prediction_50_user_pd_df = prediction_50.toPandas()[['userId','rating','prediction']].set_index('userId')
prediction_50_user_pd_df['prediction'] = prediction_50_user_pd_df['prediction'].apply(lambda x: round_to_5scale(x))
display(prediction_50_user_pd_df.plot(style=['o','rx']))

# %% [markdown]
# ### Apply model to all data and see the performance

# %%
#Best_model RMSE
alldata=best_model.transform(movie_ratings_df)
rmse = evaluator.evaluate(alldata)
print ("RMSE = "+str(rmse))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">RMSE = 0.6975433153657589
# </div>

# %%
#Best_model_50 RMSE
alldata=best_model_50.transform(movie_ratings_df)
rmse = evaluator.evaluate(alldata)
print ("RMSE = "+str(rmse))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">RMSE = 0.6874073412892818
# </div>

# %%
alldata.registerTempTable("alldata")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql 
SELECT *
FROM movies
	JOIN alldata ON movies.movieId = alldata.movieId
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movieId</th><th>title</th><th>genres</th><th>userId</th><th>movieId</th><th>rating</th><th>prediction</th></tr></thead><tbody><tr><td>148</td><td>Awfully Big Adventure, An (1995)</td><td>Drama</td><td>191</td><td>148</td><td>5.0</td><td>4.855351</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>133</td><td>471</td><td>4.0</td><td>2.416814</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>597</td><td>471</td><td>2.0</td><td>3.3838356</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>385</td><td>471</td><td>4.0</td><td>2.9433992</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>436</td><td>471</td><td>3.0</td><td>3.3313468</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>602</td><td>471</td><td>4.0</td><td>3.1600466</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>91</td><td>471</td><td>1.0</td><td>2.5822668</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>409</td><td>471</td><td>3.0</td><td>3.0681155</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>372</td><td>471</td><td>3.0</td><td>2.7291358</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>599</td><td>471</td><td>2.5</td><td>2.4970746</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>603</td><td>471</td><td>4.0</td><td>3.0207326</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>182</td><td>471</td><td>4.5</td><td>3.293565</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>218</td><td>471</td><td>4.0</td><td>3.2036498</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>474</td><td>471</td><td>3.0</td><td>3.162521</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>500</td><td>471</td><td>1.0</td><td>2.292801</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>57</td><td>471</td><td>3.0</td><td>3.1477387</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>462</td><td>471</td><td>2.5</td><td>2.4053903</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>387</td><td>471</td><td>3.0</td><td>2.6148915</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>610</td><td>471</td><td>4.0</td><td>3.330954</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>217</td><td>471</td><td>2.0</td><td>2.7944257</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>555</td><td>471</td><td>3.0</td><td>3.4999354</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>176</td><td>471</td><td>5.0</td><td>3.5753264</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>520</td><td>471</td><td>5.0</td><td>3.5087552</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>136</td><td>471</td><td>4.0</td><td>3.414276</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>171</td><td>471</td><td>3.0</td><td>3.9610012</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>273</td><td>471</td><td>5.0</td><td>3.99234</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>448</td><td>471</td><td>4.0</td><td>3.0048363</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>312</td><td>471</td><td>4.0</td><td>3.140611</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>216</td><td>471</td><td>3.0</td><td>2.9039948</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>411</td><td>471</td><td>4.0</td><td>3. ...

# %%
alldata_pd_df = alldata.toPandas()[['movieId','rating','prediction']].set_index('movieId')
alldata_pd_df.plot(style=['o','rx'])
display()

# %%
alldata_pd_df['prediction'] = alldata_pd_df['prediction'].apply(lambda x: round_to_5scale(x))
alldata_pd_df.plot(style=['o','rx'])
display()

# %%
alldata_user_pd_df = alldata.toPandas()[['userId','rating','prediction']].set_index('userId')
alldata_user_pd_df['prediction'] = alldata_user_pd_df['prediction'].apply(lambda x: round_to_5scale(x))
display(alldata_user_pd_df.plot(style=['o','rx']))

# %% [markdown]
# ### Let's look more closely on the user and movie data to decide which user to recommend.

# %%
ratings_info_df = movie_ratings_df.groupBy('movieId').avg('rating')
movie_ratings_count= movie_ratings_df.groupBy('movieId').count()
ratings_info_df = ratings_info_df.join(movie_ratings_count,'movieId','left').join(movies_df,'movieId','left')
ratings_info_df.show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-----------------+-----+--------------------+--------------------+
# movieId|      avg(rating)|count|               title|              genres|
# +-------+-----------------+-----+--------------------+--------------------+
#    1580|3.487878787878788|  165|Men in Black (a.k...|Action|Comedy|Sci-Fi|
#    2366|             3.64|   25|    King Kong (1933)|Action|Adventure|...|
#    3175|             3.58|   75| Galaxy Quest (1999)|Adventure|Comedy|...|
# +-------+-----------------+-----+--------------------+--------------------+
# only showing top 3 rows
#
# </div>

# %% [markdown]
# ### UserId order by rating count

# %%
ratings_df.groupBy("userId").count().toPandas().sort_values(by = 'count',ascending=False).head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>userId</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>345</th>
#       <td>414</td>
#       <td>2698</td>
#     </tr>
#     <tr>
#       <th>472</th>
#       <td>599</td>
#       <td>2478</td>
#     </tr>
#     <tr>
#       <th>280</th>
#       <td>474</td>
#       <td>2108</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>448</td>
#       <td>1864</td>
#     </tr>
#     <tr>
#       <th>193</th>
#       <td>274</td>
#       <td>1346</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# We will recommend user 414 and 599 as they have the highest rating count. This means the recommendations to them would be more reliable.

# %% [markdown]
# ### Histogram of rating counts

# %%
display(ratings_info_df.toPandas()['count'].hist(bins=50,log= True))

# %% [markdown]
# ### Histogram of the ratings

# %%
display(ratings_info_df.toPandas()['avg(rating)'].hist(bins=50))

# %%
fig, ax = plt.subplots()
g = sns.jointplot(x='avg(rating)', y='count', data=ratings_info_df.toPandas())
display(g.fig)

# %% [markdown]
# ## Recommend moive to users with id: 414, 599.

# %%
# use the recommendation function of ALS
ALS_recommendations = best_model.recommendForAllUsers(10)
ALS_recommendations.filter(ALS_recommendations['userId'] == 599).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+--------------------+
# userId|     recommendations|
# +------+--------------------+
#    599|[[96004, 4.252195...|
# +------+--------------------+
#
# </div>

# %% [markdown]
# We need to process the above dataframe for readability.

# %%
# Data procesing of the ALS_recommendations dataframe
from pyspark.sql.functions import explode,col
recommendations_df = (ALS_recommendations\
                      .select("userId",\
                              explode("recommendations")\
                              .alias("recommendation"))\
                      .select("userId", "recommendation.movieId",\
                              col("recommendation.rating")\
                              .alias('prediction')))
recommendations_df.show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-------+----------+
# userId|movieId|prediction|
# +------+-------+----------+
#    471|   6818| 5.1408505|
#    471|   8477| 5.0905204|
#    471|   3379|  4.981934|
# +------+-------+----------+
# only showing top 3 rows
#
# </div>

# %%
# we only recommend movies that have not been watched by users before
recommendations_df = recommendations_df.join(movies_df,["movieId"],"left").join(ratings_df,['movieId','UserId'],'left')
recommendations_df = recommendations_df.drop('timestamp')
recommendations_df = recommendations_df.filter(ratings_df.rating.isNull())
recommendations_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------+----------+--------------------+--------------------+------+
# movieId|userId|prediction|               title|              genres|rating|
# +-------+------+----------+--------------------+--------------------+------+
#    6818|   471| 5.1408505|Come and See (Idi...|           Drama|War|  null|
#    8477|   471| 5.0905204|    Jetée, La (1962)|      Romance|Sci-Fi|  null|
#    3379|   471|  4.981934| On the Beach (1959)|               Drama|  null|
#   96004|   471|  4.981934|Dragon Ball Z: Th...|Action|Adventure|...|  null|
#    5490|   471|  4.858012|  The Big Bus (1976)|       Action|Comedy|  null|
#    5915|   471|  4.858012|Victory (a.k.a. E...|    Action|Drama|War|  null|
#  132333|   471|  4.858012|         Seve (2014)|   Documentary|Drama|  null|
#   40491|   471|  4.846524|Match Factory Gir...|        Comedy|Drama|  null|
#   26326|   471| 4.6848273|Holy Mountain, Th...|               Drama|  null|
#  102217|   471|  4.677115|Bill Hicks: Revel...|              Comedy|  null|
#   96004|   463|  5.278501|Dragon Ball Z: Th...|Action|Adventure|...|  null|
#    3379|   463|  5.278501| On the Beach (1959)|               Drama|  null|
#   60943|   463| 5.0922623| Frozen River (2008)|               Drama|  null|
#    3567|   463| 4.9940257|   Bossa Nova (2000)|Comedy|Drama|Romance|  null|
#   33649|   463|  4.925018|  Saving Face (2004)|Comedy|Drama|Romance|  null|
#   92494|   463| 4.8854833|Dylan Moran: Mons...|  Comedy|Documentary|  null|
#  102217|   463| 4.8854833|Bill Hicks: Revel...|              Comedy|  null|
#   33779|   463| 4.8854833|Eddie Izzard: Dre...|              Comedy|  null|
#  171495|   463| 4.8617916|              Cosmos|  (no genres listed)|  null|
#   93988|   463|  4.814151|North &amp; South (2004)|       Drama|Romance|  null|
# +-------+------+----------+--------------------+--------------------+------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# We will only recommend movies that the users haven't watched/rated.
#
# movies recommendations for user 414

# %%
recommendations_df.filter(recommendations_df['userId'] == 414).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------+----------+--------------------+--------------------+------+
# movieId|userId|prediction|               title|              genres|rating|
# +-------+------+----------+--------------------+--------------------+------+
#   96004|   414|  5.301862|Dragon Ball Z: Th...|Action|Adventure|...|  null|
#    3379|   414|  5.301862| On the Beach (1959)|               Drama|  null|
#    6818|   414| 5.1921563|Come and See (Idi...|           Drama|War|  null|
#    8477|   414| 5.1837234|    Jetée, La (1962)|      Romance|Sci-Fi|  null|
#  132333|   414|  5.026645|         Seve (2014)|   Documentary|Drama|  null|
#    5915|   414|  5.026645|Victory (a.k.a. E...|    Action|Drama|War|  null|
#    5490|   414|  5.026645|  The Big Bus (1976)|       Action|Comedy|  null|
#    4495|   414|  4.941838|Crossing Delancey...|      Comedy|Romance|  null|
#   92494|   414| 4.9203644|Dylan Moran: Mons...|  Comedy|Documentary|  null|
#  102217|   414| 4.9203644|Bill Hicks: Revel...|              Comedy|  null|
# +-------+------+----------+--------------------+--------------------+------+
#
# </div>

# %% [markdown]
# movies recommendations for user 599

# %%
recommendations_df.filter(recommendations_df['userId'] == 599).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------+----------+--------------------+------------------+------+
# movieId|userId|prediction|               title|            genres|rating|
# +-------+------+----------+--------------------+------------------+------+
#    5490|   599| 3.9496071|  The Big Bus (1976)|     Action|Comedy|  null|
#    5915|   599| 3.9496071|Victory (a.k.a. E...|  Action|Drama|War|  null|
#  132333|   599| 3.9496071|         Seve (2014)| Documentary|Drama|  null|
#   60943|   599| 3.9102483| Frozen River (2008)|             Drama|  null|
#    4495|   599| 3.8764865|Crossing Delancey...|    Comedy|Romance|  null|
#    6818|   599| 3.8465486|Come and See (Idi...|         Drama|War|  null|
#   92494|   599| 3.8462806|Dylan Moran: Mons...|Comedy|Documentary|  null|
# +-------+------+----------+--------------------+------------------+------+
#
# </div>

# %%
# Another way is to recommendForUserSubset function
#users = ALS_recommendations.filter(ALS_recommendations['userId'] == 575)
#ALS_recommendations_target = best_model.recommendForUserSubset(users,1)
#ALS_recommendations_target.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Find the similar moives for moive with id: 464, 471

# %% [markdown]
# The similarites of different movies can be recognized from correlations of their user ratings. Let's say user A and B both gave movie 1,2 5 star rating. This indicates that the movie 1 and 2 might be highily similar.
#
# However, we have a challenge in that some of the movies have very few ratings and may end up having high correlation simply because one or two people gave them a 5 star rating. We can fix this by setting a threshold for the number of ratings. From the histogram earlier we saw a sharp decline in number of ratings from 100. Therefore we will choose this as our threshold.

# %%
movie_matrix = movie_ratings_df.toPandas().pivot_table(index='userId', columns='movieId', values='rating')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/pyarrow/__init__.py:152: UserWarning: pyarrow.open_stream is deprecated, please use pyarrow.ipc.open_stream
#   warnings.warn(&#34;pyarrow.open_stream is deprecated, please use &#34;
# </div>

# %%
def find_similar_movie(x):
  movie_x_rating = movie_matrix[x]
  similar_to_x=movie_matrix.corrwith(movie_x_rating).reset_index(level=0)
  similar_to_x.dropna(axis = 0,how = 'any',inplace=True)
  similar_to_x.columns = ['movieId','correlation']
  
  similar_to_x_df = sqlContext.createDataFrame(similar_to_x)
  similar_to_x_movie = similar_to_x_df.join(ratings_info_df,'movieId','left').toPandas()[['movieId','correlation','title','count']]
  res = similar_to_x_movie[similar_to_x_movie['count']>100].sort_values(by = 'correlation',ascending = False)
  return similar_to_x,res
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# We will only find similar movies that have been rated more than 100 times.
#
# movies similar to movie 471

# %%
# Movies similar to 471
corr_471,similar_to_471_movie = find_similar_movie(471)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/numpy/lib/function_base.py:2522: RuntimeWarning: Degrees of freedom &lt;= 0 for slice
#   c = cov(x, y, rowvar)
# /databricks/python/lib/python3.7/site-packages/numpy/lib/function_base.py:2451: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# /databricks/python/lib/python3.7/site-packages/pyarrow/__init__.py:152: UserWarning: pyarrow.open_stream is deprecated, please use pyarrow.ipc.open_stream
#   warnings.warn(&#34;pyarrow.open_stream is deprecated, please use &#34;
# </div>

# %%
corr_471.plot(kind='scatter',x = 'movieId',y='correlation')
display()

# %%
similar_to_471_movie.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>movieId</th>
#       <th>correlation</th>
#       <th>title</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2426</th>
#       <td>79132</td>
#       <td>0.973124</td>
#       <td>Inception (2010)</td>
#       <td>143</td>
#     </tr>
#     <tr>
#       <th>1788</th>
#       <td>48516</td>
#       <td>0.724861</td>
#       <td>Departed, The (2006)</td>
#       <td>107</td>
#     </tr>
#     <tr>
#       <th>2576</th>
#       <td>33794</td>
#       <td>0.677430</td>
#       <td>Batman Begins (2005)</td>
#       <td>116</td>
#     </tr>
#     <tr>
#       <th>1350</th>
#       <td>1222</td>
#       <td>0.608101</td>
#       <td>Full Metal Jacket (1987)</td>
#       <td>102</td>
#     </tr>
#     <tr>
#       <th>1229</th>
#       <td>364</td>
#       <td>0.570549</td>
#       <td>Lion King, The (1994)</td>
#       <td>172</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# movies similar to movie 464

# %%
# Movies similar to 464
corr_464,similar_to_464_movie = find_similar_movie(464)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/numpy/lib/function_base.py:2522: RuntimeWarning: Degrees of freedom &lt;= 0 for slice
#   c = cov(x, y, rowvar)
# /databricks/python/lib/python3.7/site-packages/numpy/lib/function_base.py:2451: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# /databricks/python/lib/python3.7/site-packages/pyarrow/__init__.py:152: UserWarning: pyarrow.open_stream is deprecated, please use pyarrow.ipc.open_stream
#   warnings.warn(&#34;pyarrow.open_stream is deprecated, please use &#34;
# </div>

# %%
corr_464.plot(kind='scatter',x = 'movieId',y='correlation')
display()

# %%
similar_to_464_movie.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>movieId</th>
#       <th>correlation</th>
#       <th>title</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>362</th>
#       <td>5816</td>
#       <td>1.000000</td>
#       <td>Harry Potter and the Chamber of Secrets (2002)</td>
#       <td>102</td>
#     </tr>
#     <tr>
#       <th>528</th>
#       <td>4896</td>
#       <td>0.904534</td>
#       <td>Harry Potter and the Sorcerer's Stone (a.k.a. ...</td>
#       <td>107</td>
#     </tr>
#     <tr>
#       <th>1465</th>
#       <td>58559</td>
#       <td>0.866025</td>
#       <td>Dark Knight, The (2008)</td>
#       <td>149</td>
#     </tr>
#     <tr>
#       <th>450</th>
#       <td>253</td>
#       <td>0.853913</td>
#       <td>Interview with the Vampire: The Vampire Chroni...</td>
#       <td>109</td>
#     </tr>
#     <tr>
#       <th>389</th>
#       <td>7153</td>
#       <td>0.845154</td>
#       <td>Lord of the Rings: The Return of the King, The...</td>
#       <td>185</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Write the report
# motivation
# 1. step1
# 2. step2
# 3. step3
# 4. step4
# output and conclusion

# %% [markdown]
# ## Report
# In this project, the movie data from movie lens data set which includes about 600 users and 9500 movies were analyzed to gain insights on movie recomendations to users and finding similar movies. At the beginning, we calculate the sparisity of the movie ratings which is 98.3%, this tells us that the ratings dataframe is mostly empty, which brings significance to predict the user ratings from what we have.
#
# To achieve the goal,the data was analyzed on Spark platform from perfoming data cleaning,processing to model training with Alternating Least Squares (ALS) algorithm.During which, grid search and cross validation were applied to tune the hyperparameters. It is found that using large rank and iterzations would help achieve a low RMSE. Finally, we choose a rank of 10, iterate 50 times and regPram = 0.15,a RMSE of 0.69 was achieved.This means that on average the model predicts 0.69 above or below values of the original ratings matrix.
#
# By successsfully predicting the ratings using the best model, we not only fill the rating dataframe and recommend our users with movies they have never watched, but also find similar movies through their correlations. This brings huge business value to the company.
